# %% [markdown]
# ## Data Exploration and Cleaning of the NYC Department of Building Job Applications Filing Dataset
#
# This notebook will explore some of the features of the dataset and discuss some of the logics that were used to develop the data cleaning methodology. The data cleaning is set-up in a way so machine learning can be applied to the dataset.
#
# Source dataset found [here](https://data.cityofnewyork.us/Housing-Development/DOB-Job-Application-Filings/ic3t-wcy2/)

# %%
from IPython.display import clear_output
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))

import os
import numpy as np
import pandas as pd
pd.options.display.max_columns = None
pd.options.display.max_rows = None
import re

from helper_scripts.cleaning_scripts import *
# Out:
# <style>.container { width:90% !important; }</style>

# %%
raw_data_path = os.path.join('..', 'data', 'raw', 'DOB_job_application.csv')
df = pd.read_csv(raw_data_path, low_memory=False)
df.head()
# Out:
#        Job #  Doc #   Borough House #         Street Name  Block    Lot  \
# 0  420291794      1    QUEENS  183-16      JAMAICA AVENUE  10352  00058
# 1  420291801      1    QUEENS  150-33  CENTREVILLE STREET  11556  00053
# 2  340644128      1  BROOKLYN     354      DOUGLAS STREET  00946  00015
# 3  421685439      1    QUEENS   34-56          200 STREET  06078  00031
# 4  421677974      2    QUEENS   35-37         36TH STREET  00640  00004
#
#      Bin # Job Type Job Status                Job Status Descrp  \
# 0  4438800       A3          X                       SIGNED OFF
# 1  4248973       A2          X                       SIGNED OFF
# 2  3019327       A2          X                       SIGNED OFF
# 3  4619372       NB          P             PLAN EXAM - APPROVED
# 4  4009599       A2          R  PERMIT ISSUED - ENTIRE JOB/WORK
#
#        Latest Action Date Building Type Community - Board Cluster Landmarked  \
# 0  08/02/2011 12:00:00 AM        OTHERS               412       N          N
# 1  10/31/2011 12:00:00 AM  1-2-3 FAMILY               410       N          N
# 2  03/18/2019 12:00:00 AM  1-2-3 FAMILY               306       N          N
# 3  04/09/2019 12:00:00 AM  1-2-3 FAMILY               411       N          N
# 4  11/16/2018 12:00:00 AM        OTHERS               401       N          N
#
#   Adult Estab Loft Board City Owned Little e PC Filed eFiling Filed Plumbing  \
# 0           N          N        NaN        N      NaN           NaN      NaN
# 1           N          N        NaN        N      NaN             Y        X
# 2           N          N        NaN        N      NaN             Y      NaN
# 3           N          N        NaN        N      NaN             Y        X
# 4         NaN          N        NaN      NaN      NaN             Y        X
#
#   Mechanical Boiler Fuel Burning Fuel Storage Standpipe Sprinkler Fire Alarm  \
# 0        NaN    NaN          NaN          NaN       NaN       NaN        NaN
# 1        NaN    NaN          NaN          NaN       NaN       NaN        NaN
# 2        NaN    NaN          NaN          NaN       NaN       NaN        NaN
# 3        NaN    NaN          NaN          NaN       NaN       NaN        NaN
# 4          X    NaN          NaN          NaN       NaN       NaN        NaN
#
#   Equipment Fire Suppression Curb Cut Other Other Description  \
# 0       NaN              NaN      NaN     X           ANTENNA
# 1       NaN              NaN      NaN   NaN               NaN
# 2       NaN              NaN      NaN     X         SOLAR TAX
# 3       NaN              NaN      NaN     X      GEN. CONSTR.
# 4       NaN              NaN      NaN   NaN               NaN
#
#   Applicant's First Name Applicant's Last Name Applicant Professional Title  \
# 0             MANOJKUMAR                 PATEL                           PE
# 1                 ANDREW                SAYERS                           PE
# 2                  JAMES                CLANCY                           PE
# 3                DEZHANG                  FANG                           RA
# 4                DOUGLAS                  MASS                           PE
#
#   Applicant License # Professional Cert Pre- Filing Date        Paid  \
# 0              084829                 N       11/29/2010  11/29/2010
# 1              077987                 N       11/29/2010  11/29/2010
# 2              084288                 N       11/02/2018  11/02/2018
# 3              037876                 N       11/02/2018  11/02/2018
# 4              058375                 Y       09/12/2018  09/12/2018
#
#    Fully Paid    Assigned    Approved Fully Permitted Initial Cost  \
# 0  12/29/2010  12/30/2010  01/10/2011      01/25/2011     $2000.00
# 1  11/29/2010  11/30/2010  01/21/2011      01/21/2011    $15000.00
# 2  11/02/2018  11/05/2018  11/05/2018      11/08/2018    $44726.00
# 3  11/02/2018  11/05/2018  04/09/2019             NaN        $0.00
# 4  09/12/2018         NaN         NaN             NaN   $105000.00
#
#   Total Est. Fee Fee Status  Existing Zoning Sqft  Proposed Zoning Sqft  \
# 0        $100.00   STANDARD                     0                     0
# 1        $151.50   STANDARD                     0                     0
# 2        $234.00   STANDARD                     0                     0
# 3        $243.00   STANDARD                     0                  2700
# 4       $1275.60   STANDARD                     0                     0
#
#   Horizontal Enlrgmt Vertical Enlrgmt  Enlargement SQ Footage  \
# 0                NaN              NaN                       0
# 1                NaN              NaN                       0
# 2                NaN              NaN                       0
# 3                NaN              NaN                       0
# 4                NaN              NaN                       0
#
#    Street Frontage  ExistingNo. of Stories  Proposed No. of Stories  \
# 0                0                       2                        2
# 1                0                       3                        3
# 2                0                       2                        2
# 3                0                       0                        2
# 4                0                       0                        0
#
#    Existing Height  Proposed Height Existing Dwelling Units  \
# 0               24               24                     NaN
# 1               35               35                       2
# 2               28               28                       2
# 3                0               28                     NaN
# 4                0                0                     NaN
#
#   Proposed Dwelling Units Existing Occupancy Proposed Occupancy  \
# 0                     NaN                COM                COM
# 1                       2                R-3                R-3
# 2                       2                R-3                R-3
# 3                       2                NaN                R-3
# 4                     NaN                NaN                NaN
#
#              Site Fill Zoning Dist1 Zoning Dist2 Zoning Dist3  \
# 0                  NaN         M1-2          NaN          NaN
# 1       NOT APPLICABLE           R4          NaN          NaN
# 2       NOT APPLICABLE          R6B          NaN          NaN
# 3  USE UNDER 300 CU.YD          R3A          NaN          NaN
# 4                  NaN          NaN          NaN          NaN
#
#   Special District 1 Special District 2   Owner Type Non-Profit  \
# 0                NaN                IBZ  PARTNERSHIP          N
# 1                NaN                NaN  CORPORATION          N
# 2                NaN                NaN   INDIVIDUAL          N
# 3                NaN                NaN  PARTNERSHIP          N
# 4                NaN                NaN  CORPORATION          N
#
#   Owner's First Name Owner's Last Name             Owner's Business Name  \
# 0                JOE             VIGNA                      NEW CINGULAR
# 1            ANTHONY            GURINO                   VMG REALITY LLC
# 2               MARK          CAVANAGH                               NaN
# 3                 ZE              CHEN          GREAT INVESTMENT USA LLC
# 4            WILLIAM              BOND  EIB STUDIO SQUARE LLC C/O VANBAR
#
#   Owner's House Number Owner'sHouse Street Name       City  State    Zip  \
# 0                  340           340 MT. KEMBEL  MORRISTOWN    NY  07960
# 1                96-20    96-20 ATLANTIC AVENUE  OZONE PARK    NY  11416
# 2                  354      354 DOUGLASS STREET    BROOKLYN    NY  11217
# 3                42-26         42-26 161 STREET    FLUSHING    NY  11358
# 4                  420     420 LEXINGTON AVENUE    NEW YORK    NY  10170
#
#   Owner'sPhone #                                    Job Description  \
# 0     9738964570  INSTALLING 2'X2' TELECOMMUNICATIONS EQUIPMENT ...
# 1     7186411098  INSTALLATION OF WET SPRINKLER SYSTEM OFF DOMES...
# 2     7188527096  INSTALL SOLAR PV SYSTEM ON THE EXISTING ROOFTO...
# 3     9172388321  HEREWITH FILED FOR A NEW DETACHED 2-STORY 2-FA...
# 4     2122938800     MECHANICAL AND PLUMBING WORK AS SHOWN ON PLANS
#
#                DOBRunDate  JOB_S1_NO  TOTAL_CONSTRUCTION_FLOOR_AREA  \
# 0  03/13/2019 12:00:00 AM    1841656                              0
# 1  03/13/2019 12:00:00 AM    1841667                              0
# 2  03/19/2019 12:00:00 AM    3026504                              0
# 3  04/10/2019 12:00:00 AM    3026432                           4050
# 4  11/17/2018 12:00:00 AM    3003476                              0
#
#    WITHDRAWAL_FLAG SIGNOFF_DATE SPECIAL_ACTION_STATUS SPECIAL_ACTION_DATE  \
# 0                0   08/02/2011                     N                 NaN
# 1                0   10/31/2011                     N                 NaN
# 2                0   03/18/2019                     N                 NaN
# 3                0          NaN                     N                 NaN
# 4                0          NaN                     N                 NaN
#
#   BUILDING_CLASS  JOB_NO_GOOD_COUNT  GIS_LATITUDE  GIS_LONGITUDE  \
# 0             E1                  0     40.708932     -73.776983
# 1             B2                  0     40.669071     -73.838928
# 2             B1                  0     40.679058     -73.981126
# 3             A0                  0     40.765658     -73.787240
# 4             E9                  0     40.755622     -73.925003
#
#    GIS_COUNCIL_DISTRICT  GIS_CENSUS_TRACT           GIS_NTA_NAME    GIS_BIN
# 0                  27.0             444.0                Jamaica  4438800.0
# 1                  32.0              88.0             Ozone Park  4541404.0
# 2                  39.0             131.0     Park Slope-Gowanus  3019327.0
# 3                  19.0            1099.0  Bayside-Bayside Hills        NaN
# 4                  26.0              57.0                Astoria  4009599.0

# %%
df.columns = [clean_col_name(x) for x in df.columns] ## clean-up column name: removes symbols, # --> Num, and replaces space with _
## Remove columns that will not be used for this analysis
exclude_columns = ['House_Num', 'Street_Name', 'Block', 'Lot', 'Bin_Num', 'Job_Status_Descrp', 'Latest_Action_Date', 'Applicants_First_Name', 'Applicants_Last_Name', 'Applicant_Professional_Title', 
                   'Applicant_License_Num','Professional_Cert', 'Owners_First_Name','Owners_Last_Name','Owners_Business_Name','Owners_House_Number','OwnersHouse_Street_Name',
                   'City','State','Zip','OwnersPhone_Num', 'DOBRunDate','JOB_S1_NO', 'GIS_COUNCIL_DISTRICT','GIS_CENSUS_TRACT', 'GIS_BIN']
df.drop(exclude_columns, inplace=True, axis=1)
## Convert columns that have dollar signs to float so it can be aggregated
df['Initial_Cost'], df['Total_Est_Fee'] = get_dollar_to_num(df['Initial_Cost']), get_dollar_to_num(df['Total_Est_Fee'])

df.head()
# Out:
#      Job_Num  Doc_Num   Borough Job_Type Job_Status Building_Type  \
# 0  420291794        1    QUEENS       A3          X        OTHERS
# 1  420291801        1    QUEENS       A2          X  1-2-3 FAMILY
# 2  340644128        1  BROOKLYN       A2          X  1-2-3 FAMILY
# 3  421685439        1    QUEENS       NB          P  1-2-3 FAMILY
# 4  421677974        2    QUEENS       A2          R        OTHERS
#
#   Community_Board Cluster Landmarked Adult_Estab Loft_Board City_Owned  \
# 0             412       N          N           N          N        NaN
# 1             410       N          N           N          N        NaN
# 2             306       N          N           N          N        NaN
# 3             411       N          N           N          N        NaN
# 4             401       N          N         NaN          N        NaN
#
#   Little_e PC_Filed eFiling_Filed Plumbing Mechanical Boiler Fuel_Burning  \
# 0        N      NaN           NaN      NaN        NaN    NaN          NaN
# 1        N      NaN             Y        X        NaN    NaN          NaN
# 2        N      NaN             Y      NaN        NaN    NaN          NaN
# 3        N      NaN             Y        X        NaN    NaN          NaN
# 4      NaN      NaN             Y        X          X    NaN          NaN
#
#   Fuel_Storage Standpipe Sprinkler Fire_Alarm Equipment Fire_Suppression  \
# 0          NaN       NaN       NaN        NaN       NaN              NaN
# 1          NaN       NaN       NaN        NaN       NaN              NaN
# 2          NaN       NaN       NaN        NaN       NaN              NaN
# 3          NaN       NaN       NaN        NaN       NaN              NaN
# 4          NaN       NaN       NaN        NaN       NaN              NaN
#
#   Curb_Cut Other Other_Description Pre_Filing_Date        Paid  Fully_Paid  \
# 0      NaN     X           ANTENNA      11/29/2010  11/29/2010  12/29/2010
# 1      NaN   NaN               NaN      11/29/2010  11/29/2010  11/29/2010
# 2      NaN     X         SOLAR TAX      11/02/2018  11/02/2018  11/02/2018
# 3      NaN     X      GEN. CONSTR.      11/02/2018  11/02/2018  11/02/2018
# 4      NaN   NaN               NaN      09/12/2018  09/12/2018  09/12/2018
#
#      Assigned    Approved Fully_Permitted  Initial_Cost  Total_Est_Fee  \
# 0  12/30/2010  01/10/2011      01/25/2011        2000.0          100.0
# 1  11/30/2010  01/21/2011      01/21/2011       15000.0          151.5
# 2  11/05/2018  11/05/2018      11/08/2018       44726.0          234.0
# 3  11/05/2018  04/09/2019             NaN           0.0          243.0
# 4         NaN         NaN             NaN      105000.0         1275.6
#
#   Fee_Status  Existing_Zoning_Sqft  Proposed_Zoning_Sqft Horizontal_Enlrgmt  \
# 0   STANDARD                     0                     0                NaN
# 1   STANDARD                     0                     0                NaN
# 2   STANDARD                     0                     0                NaN
# 3   STANDARD                     0                  2700                NaN
# 4   STANDARD                     0                     0                NaN
#
#   Vertical_Enlrgmt  Enlargement_SQ_Footage  Street_Frontage  \
# 0              NaN                       0                0
# 1              NaN                       0                0
# 2              NaN                       0                0
# 3              NaN                       0                0
# 4              NaN                       0                0
#
#    ExistingNo_of_Stories  Proposed_No_of_Stories  Existing_Height  \
# 0                      2                       2               24
# 1                      3                       3               35
# 2                      2                       2               28
# 3                      0                       2                0
# 4                      0                       0                0
#
#    Proposed_Height Existing_Dwelling_Units Proposed_Dwelling_Units  \
# 0               24                     NaN                     NaN
# 1               35                       2                       2
# 2               28                       2                       2
# 3               28                     NaN                       2
# 4                0                     NaN                     NaN
#
#   Existing_Occupancy Proposed_Occupancy            Site_Fill Zoning_Dist1  \
# 0                COM                COM                  NaN         M1-2
# 1                R-3                R-3       NOT APPLICABLE           R4
# 2                R-3                R-3       NOT APPLICABLE          R6B
# 3                NaN                R-3  USE UNDER 300 CU.YD          R3A
# 4                NaN                NaN                  NaN          NaN
#
#   Zoning_Dist2 Zoning_Dist3 Special_District_1 Special_District_2  \
# 0          NaN          NaN                NaN                IBZ
# 1          NaN          NaN                NaN                NaN
# 2          NaN          NaN                NaN                NaN
# 3          NaN          NaN                NaN                NaN
# 4          NaN          NaN                NaN                NaN
#
#     Owner_Type NonProfit                                    Job_Description  \
# 0  PARTNERSHIP         N  INSTALLING 2'X2' TELECOMMUNICATIONS EQUIPMENT ...
# 1  CORPORATION         N  INSTALLATION OF WET SPRINKLER SYSTEM OFF DOMES...
# 2   INDIVIDUAL         N  INSTALL SOLAR PV SYSTEM ON THE EXISTING ROOFTO...
# 3  PARTNERSHIP         N  HEREWITH FILED FOR A NEW DETACHED 2-STORY 2-FA...
# 4  CORPORATION         N     MECHANICAL AND PLUMBING WORK AS SHOWN ON PLANS
#
#    TOTAL_CONSTRUCTION_FLOOR_AREA  WITHDRAWAL_FLAG SIGNOFF_DATE  \
# 0                              0                0   08/02/2011
# 1                              0                0   10/31/2011
# 2                              0                0   03/18/2019
# 3                           4050                0          NaN
# 4                              0                0          NaN
#
#   SPECIAL_ACTION_STATUS SPECIAL_ACTION_DATE BUILDING_CLASS  JOB_NO_GOOD_COUNT  \
# 0                     N                 NaN             E1                  0
# 1                     N                 NaN             B2                  0
# 2                     N                 NaN             B1                  0
# 3                     N                 NaN             A0                  0
# 4                     N                 NaN             E9                  0
#
#    GIS_LATITUDE  GIS_LONGITUDE           GIS_NTA_NAME
# 0     40.708932     -73.776983                Jamaica
# 1     40.669071     -73.838928             Ozone Park
# 2     40.679058     -73.981126     Park Slope-Gowanus
# 3     40.765658     -73.787240  Bayside-Bayside Hills
# 4     40.755622     -73.925003                Astoria

# %% [markdown]
# For a specific filing/job with the DOB there are multiple job permit applications filed. For example, in the job below there are 5 separate documents that were filed. Most fields are duplicated information across the document numbers, but some columns contain information that appear only in that particular document number. For example, columns like *Plumbing, Mechanical, Boiler*, etc. only have the X indicator if that document number that was associated with a Plumbing work filing. When aggregating the information we need to make sure these information are not lost.
#
# Further, columns like *Other Description* and *Job Description* have unique detailed descriptions of the job across documents which could be utilized in a model.
#
# There are also details that only seem to appear on the first document, e.g. columns like *Proposed_Zoning_Sqft*, *TOTAL_CONSTRUCTION_FLOOR_AREA*, etc. Any data processing to build features for models will need to take these features of the dataset into consideration.

# %%
df[df['Job_Num']==320595940].sort_values('Doc_Num')
# Out:
#           Job_Num  Doc_Num   Borough Job_Type Job_Status Building_Type  \
# 60692   320595940        1  BROOKLYN       NB          X        OTHERS
# 60697   320595940        2  BROOKLYN       NB          X        OTHERS
# 60698   320595940        3  BROOKLYN       NB          X        OTHERS
# 798418  320595940        4  BROOKLYN       NB          D        OTHERS
# 159     320595940        5  BROOKLYN       NB          X        OTHERS
#
#        Community_Board Cluster Landmarked Adult_Estab Loft_Board City_Owned  \
# 60692              307       N          N           N          N        NaN
# 60697              307       N          N         NaN          N        NaN
# 60698              307       N          N         NaN          N        NaN
# 798418             307       N          N         NaN          N        NaN
# 159                307       N          N         NaN          N        NaN
#
#        Little_e PC_Filed eFiling_Filed Plumbing Mechanical Boiler  \
# 60692         N      NaN             Y      NaN        NaN    NaN
# 60697       NaN      NaN             Y      NaN        NaN    NaN
# 60698       NaN      NaN             Y      NaN        NaN    NaN
# 798418      NaN      NaN             Y        X          X    NaN
# 159         NaN      NaN             Y        X          X    NaN
#
#        Fuel_Burning Fuel_Storage Standpipe Sprinkler Fire_Alarm Equipment  \
# 60692           NaN          NaN       NaN       NaN        NaN         X
# 60697           NaN          NaN       NaN       NaN        NaN       NaN
# 60698           NaN          NaN       NaN       NaN        NaN       NaN
# 798418          NaN          NaN       NaN         X        NaN       NaN
# 159             NaN          NaN       NaN       NaN        NaN       NaN
#
#        Fire_Suppression Curb_Cut Other Other_Description Pre_Filing_Date  \
# 60692               NaN        X     X      GEN. CONSTR.      03/31/2014
# 60697               NaN      NaN     X        STRUCTURAL      09/03/2014
# 60698               NaN      NaN     X               SOE      09/03/2014
# 798418              NaN      NaN   NaN               NaN      02/04/2015
# 159                 NaN      NaN   NaN               NaN      08/21/2015
#
#               Paid  Fully_Paid    Assigned    Approved Fully_Permitted  \
# 60692   04/01/2014  04/01/2014  05/22/2018  10/19/2015      09/27/2016
# 60697   09/03/2014  09/03/2014  05/22/2018         NaN             NaN
# 60698   09/03/2014  09/03/2014  05/22/2018         NaN             NaN
# 798418  02/04/2015  02/04/2015         NaN         NaN             NaN
# 159     08/21/2015  08/21/2015  05/22/2018         NaN             NaN
#
#         Initial_Cost  Total_Est_Fee Fee_Status  Existing_Zoning_Sqft  \
# 60692            0.0        7834.16   STANDARD                     0
# 60697            0.0           0.00   STANDARD                     0
# 60698            0.0           0.00   STANDARD                     0
# 798418           0.0           0.00   STANDARD                     0
# 159              0.0           0.00   STANDARD                     0
#
#         Proposed_Zoning_Sqft Horizontal_Enlrgmt Vertical_Enlrgmt  \
# 60692                  20987                NaN              NaN
# 60697                      0                NaN              NaN
# 60698                      0                NaN              NaN
# 798418                     0                NaN              NaN
# 159                        0                NaN              NaN
#
#         Enlargement_SQ_Footage  Street_Frontage  ExistingNo_of_Stories  \
# 60692                        0                0                      0
# 60697                        0                0                      0
# 60698                        0                0                      0
# 798418                       0                0                      0
# 159                          0                0                      0
#
#         Proposed_No_of_Stories  Existing_Height  Proposed_Height  \
# 60692                        6                0               65
# 60697                        0                0                0
# 60698                        0                0                0
# 798418                       0                0                0
# 159                          0                0                0
#
#        Existing_Dwelling_Units Proposed_Dwelling_Units Existing_Occupancy  \
# 60692                      NaN                      74                NaN
# 60697                      NaN                     NaN                NaN
# 60698                      NaN                     NaN                NaN
# 798418                     NaN                     NaN                NaN
# 159                        NaN                     NaN                NaN
#
#        Proposed_Occupancy Site_Fill Zoning_Dist1 Zoning_Dist2 Zoning_Dist3  \
# 60692                 R-1   ON-SITE        M1-2D          NaN          NaN
# 60697                 NaN       NaN          NaN          NaN          NaN
# 60698                 NaN       NaN          NaN          NaN          NaN
# 798418                NaN       NaN          NaN          NaN          NaN
# 159                   NaN       NaN          NaN          NaN          NaN
#
#        Special_District_1 Special_District_2   Owner_Type NonProfit  \
# 60692                 NaN                NaN  PARTNERSHIP         N
# 60697                 NaN                NaN  PARTNERSHIP         N
# 60698                 NaN                NaN  PARTNERSHIP         N
# 798418                NaN                NaN   INDIVIDUAL         N
# 159                   NaN                NaN   INDIVIDUAL         N
#
#                                 Job_Description  \
# 60692                    PROPOSED 6-STORY HOTEL
# 60697                           STRUCTURAL WORK
# 60698   SHORING WORK FOR SUPPORT OF EXCAVATION.
# 798418       PLUMBING, SPRINKLER & HVAC SYSTEMS
# 159                     PLUMBING & HVAC SYSTEMS
#
#         TOTAL_CONSTRUCTION_FLOOR_AREA  WITHDRAWAL_FLAG SIGNOFF_DATE  \
# 60692                           28716                2   01/03/2019
# 60697                               0                0   01/03/2019
# 60698                               0                0   01/03/2019
# 798418                              0                0          NaN
# 159                                 0                0   01/03/2019
#
#        SPECIAL_ACTION_STATUS SPECIAL_ACTION_DATE BUILDING_CLASS  \
# 60692                      N                 NaN             H3
# 60697                      N                 NaN             H3
# 60698                      N                 NaN             H3
# 798418                     W          08/15/2015            NaN
# 159                        N                 NaN             H3
#
#         JOB_NO_GOOD_COUNT  GIS_LATITUDE  GIS_LONGITUDE      GIS_NTA_NAME
# 60692                   0     40.657099     -74.002984  Sunset Park West
# 60697                   0     40.657099     -74.002984  Sunset Park West
# 60698                   0     40.657099     -74.002984  Sunset Park West
# 798418                  0     40.657099     -74.002984  Sunset Park West
# 159                     0     40.657099     -74.002984  Sunset Park West

# %%
interim_data_path = os.path.join('..', 'data', 'interim', 'DOB_job_application.csv')
df.to_csv(interim_data_path, index=False)

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# The A2 permits (non-major alterations) seems to be ones that are filed the most. There seems to be a significant amount of A1 (major alterations) and NB (new building) filings.

# %%
df[['Job_Type']].groupby('Job_Type').size().sort_values(ascending=False)
# Out:
# Job_Type
# A2    1049908
# A3     290252
# A1     133536
# NB     118522
# DM      44622
# PA      21022
# SI       9889
# SC       6617
# dtype: int64

# %% [markdown]
# No surprises here that Manhattan and Brooklyn filings are the most.

# %%
df[['Borough']].groupby('Borough').size().sort_values(ascending=False)
# Out:
# Borough
# MANHATTAN        743920
# BROOKLYN         378727
# QUEENS           325348
# BRONX            133466
# STATEN ISLAND     92907
# dtype: int64

# %% [markdown]
# The other description columns contain useful information but could use a lot of cleaning up. For example, the term *GENERAL CONSTRUCTION* seems to be coming up in a variety of forms such as GC, GEN.CONSTR., GEN. CONSTR, etc.

# %%
df[['Other_Description']].groupby('Other_Description').size().sort_values(ascending=False)[0:100]
# Out:
# Other_Description
# GEN. CONSTR.       269735
# GC                 116239
# GEN. CONSTR         87360
# STRUCTURAL          54217
# BPP                 45171
# GEN CONST           42113
# GEN.CONSTRUCTN.     26552
# CONSTRUCTION        20462
# FACADE              19630
# SOLAR TAX           18180
# NO WORK             15421
# ANTENNA             14049
# AWNING              13128
# PARTITIONS          12774
# G.C.                12045
# GEN. CONST.         10414
# ARCHITECTURAL       10305
# SOLAR                8516
# ENL                  6160
# GEN CONSTR           5075
# GEN CONST.           4796
# FPP                  4713
# ARCH                 4641
# Structural           4402
# GEN CONSTRUCT        3637
# SOE                  3350
# CONST.               3190
# FOUNDATION           2923
# G.C                  2708
# CONSTR               2510
# CONST                2495
# GENERAL CONSTRU      2126
# TEMP INSTALL         1988
# INTERIOR DEMO        1790
# PARTITION            1590
# SHORING              1455
# DUNNAGE              1454
# structural           1407
# FACADE REPAIR        1203
# GEN CONS             1199
# ENLARGEMENT          1148
# STRUCTURE            1147
# UNDERPINNING         1091
# GEN.CONST.           1055
# SIGN STRUCTURE       1010
# CHIMNEY LINER         954
# LEGALIZATION          915
# DEMO                  832
# GENERAL CONST.        822
# GENERAL CONST         820
# GEN CONSTRUC          748
# INT. DEMO             704
# MARQUEE               697
# STR                   662
# GC NO WORK            659
# CONSTR.               648
# FACADE REPAIRS        637
# ENL.                  617
# GEN.CONSTR.           571
# ELECTRICAL            569
# DEMOLITION            541
# CIVIL                 505
# INT DEMO              494
# CABINETS/ANTENN       487
# EXCAVATION            470
# TPP                   445
# TANK REMOVAL          437
# RENOVATION            411
# GEN.CONST             405
# CABINET/ANTENNA       405
# NEW BUILDING          402
# LIGHTING              400
# GEN.CONSTRUCT         384
# PARTIAL DEMO          365
# GENERATOR             352
# GEN.CONSTRUCT.        345
# GEN'L CONSTRUCT       344
# EXTERIOR REPAIR       334
# GEN CON               328
# GEN CONSTRUCTIO       322
# SOLAR PANELS          319
# INTERIOR DEMO.        315
# SITE SAFETY PLA       314
# FIRE PROT.PLAN        306
# GEN. CONST            295
# CANOPY                292
# STRUCT                287
# MASONRY               281
# foundation            275
# LANDSCAPE             275
# GENERAL CONSTR        274
# GC,STRU               272
# TENANT PROTECT        271
# TEMP STRUCTURE        268
# ZONING                266
# SITE WORK             257
# GENERAL               249
# STOREFRONT            245
# FIRE PROTECTION       241
# RETAINING WALL        237
# dtype: int64

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# As noted in the above section document number one contains a lot of information that are not available in the other document versions. The next set of codes will identify those that have information that we want to retain.

# %%
## Filter out job# where there is no doc 1
df_doc_min = df[['Job_Num', 'Doc_Num']].groupby(['Job_Num']).min().reset_index()
df_doc_non1 = pd.merge(df, df_doc_min[df_doc_min['Doc_Num']!=1], on=['Job_Num'])
del(df_doc_min)

## Keep only non doc1 versions that do not contain relevant info
df_doc_non1 = df_doc_non1[(df_doc_non1['Proposed_Zoning_Sqft'] == 0) & (df_doc_non1['Proposed_No_of_Stories'] == 0) & (df_doc_non1['TOTAL_CONSTRUCTION_FLOOR_AREA'] == 0)][['Job_Num']]
df_clean = pd.merge(df, df_doc_non1, how='outer', indicator=True) ## Left join
del(df_doc_non1)
df_clean = df_clean[df_clean['_merge']=='left_only']
df_clean.drop('_merge', axis=1, inplace=True)

# %% [markdown]
# The next set of codes will convert the columns that only contain **X** to a numerical value so it can be aggregated.

# %%
filing_columns = ['Plumbing', 'Mechanical', 'Boiler', 'Fuel_Burning','Fuel_Storage','Standpipe','Sprinkler','Fire_Alarm','Equipment','Fire_Suppression','Curb_Cut','Other']
df_clean[filing_columns] = df_clean[filing_columns].fillna(0)
df_clean[filing_columns] = df_clean[filing_columns].replace('X', 1)
df_clean[filing_columns] = df_clean[filing_columns].replace('N', 0)
agg_columns = filing_columns + ['Initial_Cost', 'Total_Est_Fee']
df_filing_details = df_clean[['Job_Num'] + agg_columns].groupby('Job_Num').sum().reset_index()

# %% [markdown]
# Next combine the *Job_Description* columns as well as the cleaned *Other Description* column so they may be turned into useful features during the modeling phase.

# %%
## Combine feature rows across doc num into one row
df_clean['Other_Description_cleaned'] = get_clean_other_desc(df_clean['Other_Description'])
df_jobdesc = df_clean[~df_clean['Job_Description'].isna()][['Job_Num', 'Job_Description']].groupby('Job_Num')['Job_Description'].apply(list).reset_index()
df_other_desc = df_clean[~df_clean['Other_Description_cleaned'].isna()][['Job_Num', 'Other_Description_cleaned']].groupby('Job_Num')['Other_Description_cleaned'].apply(list).reset_index()
df_details = pd.merge(df_jobdesc,df_other_desc, on='Job_Num',how='outer')
df_details = pd.merge(df_details, df_filing_details, on='Job_Num',how='outer')
ignore_columns = agg_columns + ['Other_Description_cleaned', 'Job_Description', 'Other_Description']
del(df_jobdesc, df_other_desc, df_filing_details) ## Delete to free up space

# %% [markdown]
# Combine all of the datasets and output

# %%
colnames = [x for x in df_clean.columns if x not in ignore_columns]
df_proc = df_clean[(~df_clean['Fully_Permitted'].isna()) & (~df_clean['Pre_Filing_Date'].isna()) & (df_clean['Doc_Num']==1)][colnames]
df_proc = pd.merge(df_proc, df_details, on='Job_Num')

processed_data_path = os.path.join('..', 'data', 'processed', 'DOB_job_application.csv')
df_proc.to_csv(processed_data_path, index=False)
